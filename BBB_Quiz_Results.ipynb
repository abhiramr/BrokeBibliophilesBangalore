# %%
import pandas as pd

# %%
quiz = pd.read_csv("./bbb.csv")

# %%
correct = quiz[(quiz.A=="Matilda") & (quiz.B==16) & (quiz.C == "J K Rowling") & (quiz.D == 5) & (quiz.E == "Anne Frank")]

# %%
len(correct)
# Out:
# 39

# %%
correct
# Out:
#                     Email Address        A   B            C  D           E
# 2        reemamishal123@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 3           sammohan444@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 5             varshi.23@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 6           schodavarpu@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 8         09bit041@nirmauni.ac.in  Matilda  16  J K Rowling  5  Anne Frank
# 9       sharanyavinod90@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 10  sindhujavadiyampeta@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 14            meera5495@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 24        shreejaya2005@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 25             sb041286@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 26        pratikdas1989@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# ...

# %%
correct_nodup = correct.drop_duplicates()

# %%
len(correct)
# Out:
# 39

# %%
l_corr_ndup = len(correct_nodup)

# %%
correct_nodup.to_csv("./correct_nodup.csv")

# %%
correct_nodup
# Out:
#                     Email Address        A   B            C  D           E
# 2        reemamishal123@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 3           sammohan444@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 5             varshi.23@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 6           schodavarpu@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 8         09bit041@nirmauni.ac.in  Matilda  16  J K Rowling  5  Anne Frank
# 9       sharanyavinod90@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 10  sindhujavadiyampeta@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 14            meera5495@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 24        shreejaya2005@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 25             sb041286@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 26        pratikdas1989@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# ...

# %%
sample1 = correct_nodup.sample(n=int(l_corr_ndup/2))

# %%
sample2 = correct_nodup.sample(n=int(len(sample1)/2))

# %%
sample3 = correct_nodup.sample(n=int(len(sample2)/2))

# %%
sample3
# Out:
#                   Email Address        A   B            C  D           E
# 50      rashmi.canchi@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 64  archanadanappaidc@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 58        el10savio96@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 28         rajdipsura@gmail.com  Matilda  16  J K Rowling  5  Anne Frank

# %%
sample4 = correct_nodup.sample(n=int(len(sample3)/2))

# %%
sample4
# Out:
#                  Email Address        A   B            C  D           E
# 31  kulkarni.ruturaj@gmail.com  Matilda  16  J K Rowling  5  Anne Frank
# 50     rashmi.canchi@gmail.com  Matilda  16  J K Rowling  5  Anne Frank

# %%
final_winner = correct_nodup.sample(n=int(len(sample4)/2))

# %% [markdown]
# # FINAL WINNER

# %%
final_winner
# Out:
#               Email Address        A   B            C  D           E
# 24  shreejaya2005@gmail.com  Matilda  16  J K Rowling  5  Anne Frank

# %% [markdown]
# ## CONGRATS :)  shreejaya2005@gmail.com
